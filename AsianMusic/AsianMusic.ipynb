# %%
import pandas as pd
import numpy as np
import sklearn.linear_model

# %%
df_ts = pd.read_csv('transactions.csv', parse_dates=True)
df_tn = pd.read_csv('train.csv')
df_s = pd.read_csv('sample_submission_zero.csv')
df_m = pd.read_csv('members.csv')

# %%
df_ts=df_ts.sort(['msno','transaction_date'])
df_ts
# Out:
# /Users/Markos/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#                                                   msno  payment_method_id  \
# 6797850   +++FOrTS7ab3tIgIh8eWwX4FqRv8w/FoiOuyXsFvphY=                 35
# 1521480   +++IZseRRiQS9aaSkH6cMYU6bGDcxUieAi/tH67sC5s=                 38
# 1498592   +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# 17923235  +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# 58566     +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# 1914756   +++hVY1rZox/33YtvDgmKA2Frg/2qhkz12B9ylCvh8o=                 41
# 7798380   +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# 14494860  +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# 11014601  +++l/EXNMLTijfLBa8p2TUVVVp2aFGSuUI/h7mLmthw=                 39
# ...

# %%
df_ts.loc[df_ts['msno'] == 'waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=']
# Out:
#                                                  msno  payment_method_id  \
# 4261110  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=                 38
# 5459753  waLDQMmcOu2jLDaV1ddDkgCrB/jl6sD66Xzs0Vqax1Y=                 38
#
#          payment_plan_days  plan_list_price  actual_amount_paid  \
# 4261110                  7                0                   0
# 5459753                 30              149                 149
#
#          is_auto_renew  transaction_date  membership_expire_date  is_cancel
# 4261110              0          20161031                20161107          0
# 5459753              0          20170107                20170206          0

# %%
X=df_ts[['transaction_date','membership_expire_date']]
X.index=df_ts.msno
X.shape, df_tn.shape
# Out:
# ((21547746, 2), (992931, 2))

# %%
logistic=sklearn.linear_model.LogisticRegression(penalty='l2', dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='liblinear', max_iter=100, multi_class='ovr', verbose=0, warm_start=False, n_jobs=1)

# %%
logistic.fit(X, y[, sample_weight])
# Out:
#   File "<ipython-input-90-efef4812a3b1>", line 1
#     logistic.fit(X, y[, sample_weight])
#                       ^
# SyntaxError: invalid syntax

# %%
df_ts.size
# Out:
# 193929714
